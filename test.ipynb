# %%
from utils import *
from matplotlib import rc_file_defaults
import matplotlib.pyplot as plt

# %%
def plot_mean_param_evolution(thetas,num_groups, title_ = 'Group-wise Mean Parameter Evolution'):
    thetas1 = np.mean(thetas, axis=0)
    plt.rc('text', usetex = True)
    plt.rc('font', family='serif')
    width = 6
    height = 4
    fig, ax = plt.subplots(nrows=1, ncols=1) 
    fig.set_size_inches(width, height) #exact size of the figure
    fig.set_dpi(250) 
    lw = 1
    colors = ['#DBB40C','red','blue','tab:green','tab:purple','tab:brown','tab:pink','tab:gray','tab:olive']

    for i in range(num_groups):
        ax.plot(thetas1[:,i], '--', label='Group '+str(i+1), linewidth=lw, c=colors[i])

    ax.set_title(title_)
    ax.grid()
    ax.set_xlabel('Rounds')
    ax.set_ylabel('Proportion')
    ax.legend()
    plt.show()

# %%
num_rounds = 500
lambda_ = 3
eta = 0.025
N = 50
num_instances = 50
fairness_target = np.array([0.4, 0.3, 0.2, 0.1])
initial_theta = np.array([0.1, 0.2, 0.3, 0.4])
num_groups = len(fairness_target)
mean = np.ones(num_groups)*5
std = np.ones(num_groups)
acceptance_ratio = 0.6
decay = 0

applicants, admitteds, thetas = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas,num_groups)
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40

# %%
plot_mean_param_evolution(admitteds,num_groups, title_ = 'Group-wise Admission Rate Evolution')

# %%
num_rounds = 500
lambda_ = 3
eta = 0.025
N = 50
num_instances = 100
fairness_target = np.array([0.25, 0.25, 0.25, 0.25])
initial_theta = np.array([0.3, 0.2, 0.3, 0.2])
num_groups = len(fairness_target)
mean = np.array([4.75,5,5,5.25])
std = np.array([1.5,1,1,0.75])
acceptance_ratio = 0.6
decay = 0
applicants1, admitteds1, thetas1 = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas1,num_groups)
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40
# Processing instance 50
# Processing instance 60
# Processing instance 70
# Processing instance 80
# Processing instance 90

# %%
lambda_ = 6

applicants2, admitteds2, thetas2 = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas2,num_groups)
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40
# Processing instance 50
# Processing instance 60
# Processing instance 70
# Processing instance 80
# Processing instance 90

# %%
lambda_ = 12

applicants3, admitteds3, thetas3 = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas3,num_groups)
plot_mean_param_evolution(admitteds3,num_groups, 'Group-wise Admitted Candidate Proportion Evolution')
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40
# Processing instance 50
# Processing instance 60
# Processing instance 70
# Processing instance 80
# Processing instance 90

# %%
num_rounds = 500
lambda_ = 3
eta = 0.025
N = 50
num_instances = 50
num_groups = 3
fairness_target = np.ones([num_groups])/num_groups
initial_theta = (np.arange(num_groups)+1)/(num_groups*(num_groups+1)/2)
mean = np.ones(num_groups)*5
std = np.ones(num_groups)
acceptance_ratio = 0.6
decay = 0

applicants, admitteds, thetas = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas,num_groups)
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40

# %%
num_rounds = 500
lambda_ = 3
eta = 0.025
N = 50
num_instances = 50
num_groups = 4
fairness_target = np.ones([num_groups])/num_groups
initial_theta = (np.arange(num_groups)+1)/(num_groups*(num_groups+1)/2)
mean = np.ones(num_groups)*5
std = np.ones(num_groups)
acceptance_ratio = 0.6
decay = 0

applicants, admitteds, thetas = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas,num_groups)
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40

# %%
num_rounds = 500
lambda_ = 3
eta = 0.025
N = 50
num_instances = 50
num_groups = 5
fairness_target = np.ones([num_groups])/num_groups
initial_theta = (np.arange(num_groups)+1)/(num_groups*(num_groups+1)/2)
mean = np.ones(num_groups)*5
std = np.ones(num_groups)
acceptance_ratio = 0.6
decay = 0

applicants, admitteds, thetas = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas,num_groups)
# Out:
# Processing instance 0
# Processing instance 10
# Processing instance 20
# Processing instance 30
# Processing instance 40

# %%
num_rounds = 500
lambda_ = 3
eta = 0.025
N = 50
num_instances = 50
num_groups = 6
fairness_target = np.ones([num_groups])/num_groups
initial_theta = (np.arange(num_groups)+1)/(num_groups*(num_groups+1)/2)
mean = np.ones(num_groups)*5
std = np.ones(num_groups)
acceptance_ratio = 0.6
decay = 0

applicants, admitteds, thetas = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
plot_mean_param_evolution(thetas,num_groups)
# Out:
# Processing instance 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      11 acceptance_ratio = 0.6
#      12 decay = 0
# ---> 14 applicants, admitteds, thetas = process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
#      15 plot_mean_param_evolution(thetas,num_groups)
#
# File ~/Desktop/coursework/ethics/project/code/utils.py:114, in process_multigroup(N, mean, std, acceptance_ratio, fairness_target, initial_theta, lambda_, eta, num_instances, num_rounds, decay)
#     111         break
#     113 if not np.any(optimal_actions_table[tuple(state)]):
# --> 114     action_list = list(possible_actions(num_groups, int(N*acceptance_ratio), state))
#     115     reward_list = np.zeros(len(action_list))
#     116     for i in range(len(action_list)):
#
# ...
